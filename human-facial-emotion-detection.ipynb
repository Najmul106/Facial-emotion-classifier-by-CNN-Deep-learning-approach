# %%
# Basic Imports 
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Keras Imports 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau

# sklearn imports
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# 2025-07-19 15:46:02.389267: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752939962.558913      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752939962.608591      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
data_dir = '/kaggle/input/face-expression-recognition-dataset/images'
train_dir = os.path.join(data_dir, 'train')
validation_dir = os.path.join(data_dir, 'validation')

# %%
# Image Data Generator
train_datagen = ImageDataGenerator(
    rescale=1./255,  
    rotation_range=20,
    zoom_range=0.2, 
    horizontal_flip=True
)
validation_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    class_mode='categorical',
    color_mode='grayscale'
)


validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(48, 48),
    batch_size=64,
    class_mode='categorical',
    color_mode='grayscale'
)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %%
class_names = list(train_generator.class_indices.keys())

images, labels = next(train_generator)
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].reshape(48, 48), cmap='gray')
    plt.title(class_names[np.argmax(labels[i])])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# 3. CNN Model Architecture
model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(256, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    Dense(7, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1752940003.299357      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 46, 46, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 21, 21, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 21, 21, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,474,759 (9.44 MB)
#  Trainable params: 2,472,839 (9.43 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)

# Model Training
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752940023.845992     123 service.cc:148] XLA service 0x7e18f40088f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752940023.846764     123 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1752940024.364626     123 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/451 ━━━━━━━━━━━━━━━━━━━━ 1:18:11 10s/step - accuracy: 0.1875 - loss: 2.7239
# I0000 00:00:1752940028.994798     123 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 162s 337ms/step - accuracy: 0.2325 - loss: 2.4043 - val_accuracy: 0.2890 - val_loss: 1.9835 - learning_rate: 0.0010
# Epoch 2/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 87ms/step - accuracy: 0.3700 - loss: 1.6614 - val_accuracy: 0.4304 - val_loss: 1.4908 - learning_rate: 0.0010
# Epoch 3/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 45s 99ms/step - accuracy: 0.4294 - loss: 1.4829 - val_accuracy: 0.4817 - val_loss: 1.3646 - learning_rate: 0.0010
# Epoch 4/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 47s 105ms/step - accuracy: 0.4543 - loss: 1.4238 - val_accuracy: 0.4591 - val_loss: 1.4053 - learning_rate: 0.0010
# Epoch 5/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 45s 100ms/step - accuracy: 0.4808 - loss: 1.3637 - val_accuracy: 0.4958 - val_loss: 1.3216 - learning_rate: 0.0010
# Epoch 6/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 43s 96ms/step - accuracy: 0.4957 - loss: 1.3324 - val_accuracy: 0.4990 - val_loss: 1.3699 - learning_rate: 0.0010
# Epoch 7/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 43s 95ms/step - accuracy: 0.4986 - loss: 1.3097 - val_accuracy: 0.3742 - val_loss: 1.7624 - learning_rate: 0.0010
# Epoch 8/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 42s 94ms/step - accuracy: 0.5110 - loss: 1.2782 - val_accuracy: 0.5361 - val_loss: 1.2195 - learning_rate: 0.0010
# Epoch 9/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 87ms/step - accuracy: 0.5231 - loss: 1.2569 - val_accuracy: 0.5177 - val_loss: 1.3168 - learning_rate: 0.0010
# Epoch 10/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 89ms/step - accuracy: 0.5291 - loss: 1.2391 - val_accuracy: 0.5323 - val_loss: 1.2398 - learning_rate: 0.0010
# Epoch 11/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 87ms/step - accuracy: 0.5275 - loss: 1.2302 - val_accuracy: 0.5572 - val_loss: 1.1848 - learning_rate: 0.0010
# Epoch 12/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 86ms/step - accuracy: 0.5404 - loss: 1.2064 - val_accuracy: 0.5754 - val_loss: 1.1761 - learning_rate: 0.0010
# Epoch 13/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 86ms/step - accuracy: 0.5483 - loss: 1.1873 - val_accuracy: 0.5410 - val_loss: 1.2488 - learning_rate: 0.0010
# Epoch 14/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 43s 95ms/step - accuracy: 0.5474 - loss: 1.1943 - val_accuracy: 0.5439 - val_loss: 1.2144 - learning_rate: 0.0010
# Epoch 15/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5519 - loss: 1.1812
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.5519 - loss: 1.1812 - val_accuracy: 0.5367 - val_loss: 1.2603 - learning_rate: 0.0010
# Epoch 16/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 88ms/step - accuracy: 0.5563 - loss: 1.1494 - val_accuracy: 0.6037 - val_loss: 1.0629 - learning_rate: 2.0000e-04
# Epoch 17/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.5782 - loss: 1.1127 - val_accuracy: 0.5989 - val_loss: 1.0877 - learning_rate: 2.0000e-04
# Epoch 18/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - accuracy: 0.5734 - loss: 1.1194 - val_accuracy: 0.6136 - val_loss: 1.0394 - learning_rate: 2.0000e-04
# Epoch 19/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - accuracy: 0.5915 - loss: 1.0892 - val_accuracy: 0.6199 - val_loss: 1.0194 - learning_rate: 2.0000e-04
# Epoch 20/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.5842 - loss: 1.0901 - val_accuracy: 0.5679 - val_loss: 1.1801 - learning_rate: 2.0000e-04
# Epoch 21/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 89ms/step - accuracy: 0.5917 - loss: 1.0796 - val_accuracy: 0.6261 - val_loss: 1.0088 - learning_rate: 2.0000e-04
# Epoch 22/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 87ms/step - accuracy: 0.5884 - loss: 1.0862 - val_accuracy: 0.6257 - val_loss: 1.0011 - learning_rate: 2.0000e-04
# Epoch 23/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 87ms/step - accuracy: 0.5885 - loss: 1.0775 - val_accuracy: 0.6226 - val_loss: 1.0185 - learning_rate: 2.0000e-04
# Epoch 24/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 87ms/step - accuracy: 0.5948 - loss: 1.0737 - val_accuracy: 0.5736 - val_loss: 1.1770 - learning_rate: 2.0000e-04
# Epoch 25/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 87ms/step - accuracy: 0.6008 - loss: 1.0678 - val_accuracy: 0.6267 - val_loss: 0.9993 - learning_rate: 2.0000e-04
# Epoch 26/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.5947 - loss: 1.0746 - val_accuracy: 0.6264 - val_loss: 1.0100 - learning_rate: 2.0000e-04
# Epoch 27/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 87ms/step - accuracy: 0.5954 - loss: 1.0608 - val_accuracy: 0.6295 - val_loss: 0.9936 - learning_rate: 2.0000e-04
# Epoch 28/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.6080 - loss: 1.0458 - val_accuracy: 0.6332 - val_loss: 0.9916 - learning_rate: 2.0000e-04
# Epoch 29/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 89ms/step - accuracy: 0.6079 - loss: 1.0509 - val_accuracy: 0.6220 - val_loss: 1.0196 - learning_rate: 2.0000e-04
# Epoch 30/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 89ms/step - accuracy: 0.6049 - loss: 1.0357 - val_accuracy: 0.6252 - val_loss: 1.0211 - learning_rate: 2.0000e-04
# Epoch 31/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6065 - loss: 1.0418
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 89ms/step - accuracy: 0.6065 - loss: 1.0418 - val_accuracy: 0.6151 - val_loss: 1.0454 - learning_rate: 2.0000e-04
# Epoch 32/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - accuracy: 0.6121 - loss: 1.0268 - val_accuracy: 0.6366 - val_loss: 0.9803 - learning_rate: 4.0000e-05
# Epoch 33/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 90ms/step - accuracy: 0.6093 - loss: 1.0289 - val_accuracy: 0.6374 - val_loss: 0.9803 - learning_rate: 4.0000e-05
# Epoch 34/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 89ms/step - accuracy: 0.6177 - loss: 1.0191 - val_accuracy: 0.6325 - val_loss: 0.9931 - learning_rate: 4.0000e-05
# Epoch 35/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6092 - loss: 1.0372
# Epoch 35: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.6092 - loss: 1.0371 - val_accuracy: 0.6398 - val_loss: 0.9807 - learning_rate: 4.0000e-05
# Epoch 36/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 89ms/step - accuracy: 0.6076 - loss: 1.0251 - val_accuracy: 0.6398 - val_loss: 0.9754 - learning_rate: 8.0000e-06
# Epoch 37/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.6157 - loss: 1.0187 - val_accuracy: 0.6438 - val_loss: 0.9747 - learning_rate: 8.0000e-06
# Epoch 38/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 41s 90ms/step - accuracy: 0.6129 - loss: 1.0322 - val_accuracy: 0.6404 - val_loss: 0.9779 - learning_rate: 8.0000e-06
# Epoch 39/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 86ms/step - accuracy: 0.6162 - loss: 1.0140 - val_accuracy: 0.6428 - val_loss: 0.9739 - learning_rate: 8.0000e-06
# Epoch 40/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.6170 - loss: 1.0238 - val_accuracy: 0.6397 - val_loss: 0.9758 - learning_rate: 8.0000e-06
# Epoch 41/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 38s 85ms/step - accuracy: 0.6078 - loss: 1.0285 - val_accuracy: 0.6422 - val_loss: 0.9719 - learning_rate: 8.0000e-06
# Epoch 42/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 86ms/step - accuracy: 0.6202 - loss: 1.0082 - val_accuracy: 0.6390 - val_loss: 0.9803 - learning_rate: 8.0000e-06
# Epoch 43/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 38s 85ms/step - accuracy: 0.6147 - loss: 1.0166 - val_accuracy: 0.6431 - val_loss: 0.9722 - learning_rate: 8.0000e-06
# Epoch 44/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6188 - loss: 1.0095
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.6188 - loss: 1.0095 - val_accuracy: 0.6414 - val_loss: 0.9748 - learning_rate: 8.0000e-06
# Epoch 45/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 39s 87ms/step - accuracy: 0.6108 - loss: 1.0186 - val_accuracy: 0.6404 - val_loss: 0.9753 - learning_rate: 1.6000e-06
# Epoch 46/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 38s 85ms/step - accuracy: 0.6200 - loss: 1.0171 - val_accuracy: 0.6397 - val_loss: 0.9767 - learning_rate: 1.6000e-06

# %%
# 6. Evaluation - Classification Report & Confusion Matrix
val_images, val_labels = next(validation_generator)
predictions = model.predict(val_images)
y_true = np.argmax(val_labels, axis=1)
y_pred = np.argmax(predictions, axis=1)

print(classification_report(y_true, y_pred))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#               precision    recall  f1-score   support
#
#            0       0.56      0.69      0.62        13
#            2       0.67      0.22      0.33         9
#            3       0.87      0.93      0.90        14
#            4       0.60      0.75      0.67        12
#            5       0.33      0.25      0.29         8
#            6       0.78      0.88      0.82         8
#
#     accuracy                           0.66        64
#    macro avg       0.63      0.62      0.60        64
# weighted avg       0.65      0.66      0.63        64

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import numpy as np

def detect_emotion(image_path):
    img = image.load_img(image_path, target_size=(48, 48), color_mode='grayscale')
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    prediction = model.predict(img_array)
    predicted_index = np.argmax(prediction)
    predicted_class = class_names[predicted_index]
    confidence = round(prediction[0][predicted_index] * 100, 2)  # Confidence in %

    # Display the image with the predicted label and confidence
    plt.imshow(img, cmap='gray')
    plt.title(f'Predicted Emotion: {predicted_class} ({confidence}%)')
    plt.axis('off')
    plt.show()

    return predicted_class, confidence

# %%
# Example Detection
print(detect_emotion('/kaggle/input/face-expression-recognition-dataset/images/train/happy/10005.jpg'))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ('happy', 99.03)

# %%
# Example Detection
print(detect_emotion('/kaggle/input/face-expression-recognition-dataset/images/train/surprise/10249.jpg'))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ('surprise', 92.99)

# %%
# 8. Save Model
model.save('emotion_detection.h5')

# %%
class_names
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
